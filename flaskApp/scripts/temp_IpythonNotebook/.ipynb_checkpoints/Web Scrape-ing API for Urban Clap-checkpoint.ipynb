# %%
import urllib.error
from urllib.request import urlopen, Request

def url_download(url, user_agent="wswp" ,num_retries = 0):
    print("Downloading url :" + str(url))
    headers = {'User-Agent': 'Mozilla/5.0'}
    request = Request(url, headers=headers)
    try:
        html = urlopen(request).read()
        html = html.decode('utf-8')
    except urllib.error.HTTPError as e:
        print('HTTPError: {}'.format(e.code))
        if (e.code >= 500 and e.code < 600 and num_retries>0):
            html = url_download(url,num_retries-1)
        else:
            html = None
    except urllib.error.URLError as e:
        print('URLError: {}'.format(e.reason))
        html = None
    except SocketError as e:
        print('SocketError: {}'.format(e))
        html = None
    except:
        print(e)
    return html

# %%
html = url_download("https://www.urbanclap.com/mumbai-ac-service-repair")
# Out:
# Downloading url :https://www.urbanclap.com/mumbai-ac-service-repair

# %%
html
# Out:
# '<!doctype html>\n<html lang="en-in" data-reactroot=""><head><title data-react-helmet="true">AC Service in Mumbai | Jet Servicing @ 499 - UrbanClap Fulfilled</title><meta data-react-helmet="true" charSet="utf-8"/><meta data-react-helmet="true" name="theme-color" content="#222"/><meta data-react-helmet="true" name="norton-safeweb-site-verification" content="6andf9y2ncz6wk-8i73cd82rnmw69t2g8pa633xuihr-677winpu9ms3nxdrvr50bzekl6526l87lcsa3lh3bi68xzo4k6myi0q8sk0o0lk7psem4bjh6ssb4d02fo5h"/><meta data-react-helmet="true" property="og:locale" content="en_US"/><meta data-react-helmet="true" property="og:card" content="summary"/><meta data-react-helmet="true" property="og:image:width" content="200"/><meta data-react-helmet="true" property="og:image:height" content="200"/><meta data-react-helmet="true" property="al:ios:url" content="urbanclap://"/><meta data-react-helmet="true" property="al:ios:app_store_id" content="1032480595"/><meta data-react-helmet="true" property="al:ios:app_name" content="UrbanClap - Local Services"/><meta data-react-helmet="true" property="al:android:url" content="urbanclap://"/><meta data-react-helmet="true" property="al:android:app_name" content="UrbanClap - Local Services"/><meta data-react-helmet="true" property="al:android:package" content="com.urbanclap.urbanclap"/><meta data-react-helmet="true" property="al:web:url" content="https://www.urbanclap.com"/><meta data-react-helmet="true" property="p:domain_verify" content="bed574f3ae6344449231e95439a7d148"/><meta data-react-helmet="true" property="p:domain_verify" content="1bba3a691f2f483fb62f760ebbe4d0e3"/><meta data-react-helmet="true" property="apple-itunes-app" content="app-id=1032480595"/><meta data-react-helmet="true" property="google-site-verification" content="m3sCLJqA1CcTVq_X2rH_3o8BpmsG4Zjklk8OFtVuxws"/><meta data-react-helmet="true" name="description" content="Trusted AC service in Mumbai with 30 Day Service Guarantee, Well Equipped and Trained Technician with a proper background check, Genuine parts at fixed pricing. Doorstep service within 90 minutes."/><meta data-react-helmet="true" property="og:title" content="AC Service in Mumbai | Jet Servicing @ 499 - UrbanClap Fulfilled"/><meta data-react-helmet="true" property="og:type" content="company"/><meta data-react-helmet="true" property="og:url"/><meta data-react-helmet="true" property="og:image" content="//res.cloudinary.com/urbanclap/image/upload/v1485340528/web-assets/uc-web-logo.png"/><meta data-react-helmet="true" property="og:site_name" content="Urbanclap"/><meta data-react-helmet="true" property="og:description"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1"/><meta name="google-site-verification" content="m3sCLJqA1CcTVq_X2rH_3o8BpmsG4Zjklk8OFtVuxws"/><meta name="google-signin-scope" content="profile email"/><meta name="google-signin-client_id" content="614433729343-ishorc4j8ljc5vdvre5q0jt6ukji6n3b.apps.googleusercontent.com"/><link rel="dns-prefetch" href="https://static.urbanclap.com"/><link rel="dns-prefetch" href="https://res.cloudinary.com"/><link rel="preconnect" href="https://static.urbanclap.com"/><link rel="preconnect" href="https://res.cloudinary.com"/><link rel="manifest" href="/manifest.json"/><link rel="shortcut icon" href="/favicon.ico"/><script>!function(e,t){var i=e.urbanclap=e.urbanclap||{};(i.wetest=i.wetest||{}).replay={version:"1.0.0",config:{getExpUrl:"https://www.urbanclap.com/api/v1/webexperiments/get",waitTime:600,loopTime:100,replayTime:2500},init:function(){var i=e.location.search;if("string"==typeof i&&-1!==i.indexOf("abtest")){var s=t.createElement("script");return s.src="https://static.urbanclap.com/js/we-test.js",void t.getElementsByTagName("head")[0].appendChild(s)}if("string"==typeof i&&-1!==i.indexOf("versiona")&&this.setVersion("A"),"string"==typeof i&&-1!==i.indexOf("versionb")&&this.setVersion("B"),this.version=this.getVersion(),this.status=1,"A"===this.version)return this.status=2,!1;this.toggleDisplay(0),this.fireXhr( ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html,'html.parser')
